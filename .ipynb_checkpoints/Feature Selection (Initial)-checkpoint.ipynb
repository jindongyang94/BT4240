# %%
# Data feature selection
import pandas as pd
import numpy as np

data = pd.read_csv("final.csv", index_col=0)

# %%
data.head()
# Out:
#              Id    idhogar  Target  hacdor  hacapo  v14a  refrig  paredblolad  \
# 0  ID_279628684  21eb7fcc1       4       0       0     1       1            1
# 1  ID_f29eb3ddd  0e5d7a658       4       0       0     1       1            0
# 2  ID_68de51c94  2c7317ea8       4       0       0     1       1            0
# 3  ID_ec05b1a7b  2b58d945f       4       0       0     1       1            1
# 4  ID_1284f8aad  d6dae86b7       4       1       0     1       1            1
#
#    paredzocalo  paredpreb     ...      escolari-min  escolari-max  \
# 0            0          0     ...                10            10
# 1            0          0     ...                12            12
# 2            0          0     ...                11            11
# 3            0          0     ...                 2            11
# 4            0          0     ...                 0            11
#
#    escolari-sum  escolari-std  escolari-range_  age-min  age-max  age-sum  \
# 0            10      0.000000                0       43       43       43
# 1            12      0.000000                0       67       67       67
# 2            11      0.000000                0       92       92       92
# 3            33      4.272002                9        8       38      100
# 4            23      5.123475               11        7       30       76
#
#      age-std  age-range_
# 0   0.000000           0
# 1   0.000000           0
# 2   0.000000           0
# 3  14.899664          30
# 4  11.690452          23
#
# [5 rows x 217 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2973 entries, 0 to 2972
# Columns: 217 entries, Id to age-range_
# dtypes: bool(1), float64(13), int64(201), object(2)
# memory usage: 4.9+ MB

# %%
#Split data into variables types - boolean, categorical, continuous, ID
bool_var = list(data.select_dtypes('bool'))
cont_var = list(data.select_dtypes('float64'))
cat_var = list(data.select_dtypes('int64'))
id_var = list(data.select_dtypes('object'))

# %%
###1. Chi-Squared Test on Categorical Variables
#Use Chi-square test to find which categorical variables have a significant relationship with target
#feature.

#Get dataset with only categorical variables
cat_data = data[id_var + cat_var + bool_var]
cat_data.head()
# Out:
#              Id    idhogar  Target  hacdor  hacapo  v14a  refrig  paredblolad  \
# 0  ID_279628684  21eb7fcc1       4       0       0     1       1            1
# 1  ID_f29eb3ddd  0e5d7a658       4       0       0     1       1            0
# 2  ID_68de51c94  2c7317ea8       4       0       0     1       1            0
# 3  ID_ec05b1a7b  2b58d945f       4       0       0     1       1            1
# 4  ID_1284f8aad  d6dae86b7       4       1       0     1       1            1
#
#    paredzocalo  paredpreb      ...       mobilephone-range_  escolari-min  \
# 0            0          0      ...                        0            10
# 1            0          0      ...                        0            12
# 2            0          0      ...                        0            11
# 3            0          0      ...                        0             2
# 4            0          0      ...                        0             0
#
#    escolari-max  escolari-sum  escolari-range_  age-min  age-max  age-sum  \
# 0            10            10                0       43       43       43
# 1            12            12                0       67       67       67
# 2            11            11                0       92       92       92
# 3            11            33                9        8       38      100
# 4            11            23               11        7       30       76
#
#    age-range_  v2a1-missing
# 0           0         False
# 1           0         False
# 2           0         False
# 3          30         False
# 4          23         False
#
# [5 rows x 204 columns]

# %%
#Chi Square Test Script: http://www.handsonmachinelearning.com/blog/2AeuRL/chi-square-feature-selection-in-python

import scipy.stats as stats
from scipy.stats import chi2_contingency

class ChiSquare:
    def __init__(self, dataframe):
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfObserved = None
        self.dfExpected = None
    
    #Compares the p-value against this threshold and determines if variable is as important feature.
    #Input: the name of a column X and the alpha value(threshold to determine if to reject/accept null hypothesis 
    #of the Chi-Square test of independence)
    #to_remove is a list of columns to be removed
    #Output: Print if the variable X is important or if not. 
    def _print_chisquare_result(self, colX, alpha, to_remove):
        result = ""
        if self.p<alpha:
            result="{0} is IMPORTANT for Prediction".format(colX)
        else:
            result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)
            to_remove = to_remove.append(colX)

        print(result)
        
        
    #Input: two column names, colX and colY - the two variables being compared. 
    #colY is target Feature, ColX is the feature you are testing against. 
    #The last variable is Alpha which we default to 0.05.
    def TestIndependence(self,colX,colY, to_remove, alpha=0.05):
        #convert colX and colY to string types
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)
        
        #Calculate frequency counts using the pandas crosstab function. 
        #The observed and expected frequencies are stored in the dfObserved and dfExpected dataframes as they are calculated. 
        self.dfObserved = pd.crosstab(Y,X) 
        
        #use the scipy function chi2_contingency to calculate the Chi-Statistic, P-Value, Degrees of Freedom and the expected frequencies
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        self.p = p
        self.chi2 = chi2
        self.dof = dof 
        
        self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)
        
        self._print_chisquare_result(colX,alpha, to_remove)

# %%
#Initialize ChiSquare Class
cT = ChiSquare(cat_data)

#Feature Selection
testColumns = (bool_var + cat_var)
testColumns.remove('Target')
remove_list = []
chi2_summary = pd.DataFrame(columns=['variable_name', 'chi2', 'p-val', 'dof'])
for var in testColumns:
    cT.TestIndependence(colX=var,colY="Target",to_remove=remove_list)
    chi2_summary.loc[len(chi2_summary)] = [var, cT.chi2, cT.p, cT.dof]
# Out:
# v2a1-missing is IMPORTANT for Prediction
# hacdor is IMPORTANT for Prediction
# hacapo is IMPORTANT for Prediction
# v14a is IMPORTANT for Prediction
# refrig is IMPORTANT for Prediction
# paredblolad is IMPORTANT for Prediction
# paredzocalo is IMPORTANT for Prediction
# paredpreb is IMPORTANT for Prediction
# pisocemento is IMPORTANT for Prediction
# pareddes is IMPORTANT for Prediction
# paredmad is IMPORTANT for Prediction
# paredzinc is IMPORTANT for Prediction
# paredfibras is IMPORTANT for Prediction
# paredother is NOT an important predictor. (Discard paredother from model)
# pisomoscer is IMPORTANT for Prediction
# pisoother is NOT an important predictor. (Discard pisoother from model)
# pisonatur is IMPORTANT for Prediction
# pisonotiene is IMPORTANT for Prediction
# pisomadera is IMPORTANT for Prediction
# techozinc is NOT an important predictor. (Discard techozinc from model)
# techoentrepiso is NOT an important predictor. (Discard techoentrepiso from model)
# techocane is IMPORTANT for Prediction
# techootro is NOT an important predictor. (Discard techootro from model)
# cielorazo is IMPORTANT for Prediction
# abastaguadentro is IMPORTANT for Prediction
# abastaguafuera is NOT an important predictor. (Discard abastaguafuera from model)
# abastaguano is IMPORTANT for Prediction
# public is NOT an important predictor. (Discard public from model)
# planpri is NOT an important predictor. (Discard planpri from model)
# noelec is IMPORTANT for Prediction
# coopele is NOT an important predictor. (Discard coopele from model)
# sanitario1 is NOT an important predictor. (Discard sanitario1 from model)
# sanitario2 is IMPORTANT for Prediction
# sanitario3 is IMPORTANT for Prediction
# sanitario5 is IMPORTANT for Prediction
# sanitario6 is NOT an important predictor. (Discard sanitario6 from model)
# energcocinar1 is IMPORTANT for Prediction
# energcocinar2 is IMPORTANT for Prediction
# energcocinar3 is IMPORTANT for Prediction
# energcocinar4 is IMPORTANT for Prediction
# elimbasu1 is IMPORTANT for Prediction
# elimbasu2 is IMPORTANT for Prediction
# elimbasu3 is IMPORTANT for Prediction
# elimbasu4 is IMPORTANT for Prediction
# elimbasu5 is NOT an important predictor. (Discard elimbasu5 from model)
# elimbasu6 is NOT an important predictor. (Discard elimbasu6 from model)
# epared1 is IMPORTANT for Prediction
# epared2 is IMPORTANT for Prediction
# epared3 is IMPORTANT for Prediction
# etecho1 is IMPORTANT for Prediction
# etecho2 is IMPORTANT for Prediction
# etecho3 is IMPORTANT for Prediction
# eviv1 is IMPORTANT for Prediction
# eviv2 is IMPORTANT for Prediction
# eviv3 is IMPORTANT for Prediction
# tipovivi1 is NOT an important predictor. (Discard tipovivi1 from model)
# tipovivi2 is IMPORTANT for Prediction
# tipovivi3 is NOT an important predictor. (Discard tipovivi3 from model)
# tipovivi4 is IMPORTANT for Prediction
# tipovivi5 is IMPORTANT for Prediction
# computer is IMPORTANT for Prediction
# television is IMPORTANT for Prediction
# lugar1 is IMPORTANT for Prediction
# lugar2 is NOT an important predictor. (Discard lugar2 from model)
# lugar3 is IMPORTANT for Prediction
# lugar4 is IMPORTANT for Prediction
# lugar5 is IMPORTANT for Prediction
# lugar6 is NOT an important predictor. (Discard lugar6 from model)
# area1 is IMPORTANT for Prediction
# area2 is IMPORTANT for Prediction
# edjefe is IMPORTANT for Prediction
# edjefa is IMPORTANT for Prediction
# rooms is IMPORTANT for Prediction
# r4h1 is IMPORTANT for Prediction
# r4h2 is IMPORTANT for Prediction
# r4h3 is IMPORTANT for Prediction
# r4m1 is IMPORTANT for Prediction
# r4m2 is IMPORTANT for Prediction
# r4m3 is IMPORTANT for Prediction
# r4t1 is IMPORTANT for Prediction
# r4t2 is IMPORTANT for Prediction
# r4t3 is IMPORTANT for Prediction
# tamhog is IMPORTANT for Prediction
# tamviv is IMPORTANT for Prediction
# hhsize is IMPORTANT for Prediction
# hogar_nin is IMPORTANT for Prediction
# hogar_adul is IMPORTANT for Prediction
# hogar_mayor is IMPORTANT for Prediction
# hogar_total is IMPORTANT for Prediction
# bedrooms is IMPORTANT for Prediction
# qmobilephone is IMPORTANT for Prediction
# hhsize-diff is NOT an important predictor. (Discard hhsize-diff from model)
# v18q-min is IMPORTANT for Prediction
# v18q-sum is IMPORTANT for Prediction
# v18q-count is IMPORTANT for Prediction
# v18q-range_ is NOT an important predictor. (Discard v18q-range_ from model)
# dis-min is IMPORTANT for Prediction
# dis-max is IMPORTANT for Prediction
# dis-sum is IMPORTANT for Prediction
# dis-range_ is IMPORTANT for Prediction
# male-min is IMPORTANT for Prediction
# male-max is NOT an important predictor. (Discard male-max from model)
# male-sum is IMPORTANT for Prediction
# male-range_ is NOT an important predictor. (Discard male-range_ from model)
# female-sum is IMPORTANT for Prediction
# estadocivil1-min is NOT an important predictor. (Discard estadocivil1-min from model)
# estadocivil1-max is IMPORTANT for Prediction
# estadocivil1-sum is IMPORTANT for Prediction
# estadocivil2-min is NOT an important predictor. (Discard estadocivil2-min from model)
# estadocivil2-max is IMPORTANT for Prediction
# estadocivil2-range_ is IMPORTANT for Prediction
# estadocivil3-min is IMPORTANT for Prediction
# estadocivil3-max is IMPORTANT for Prediction
# estadocivil3-range_ is IMPORTANT for Prediction
# estadocivil4-min is IMPORTANT for Prediction
# estadocivil4-max is IMPORTANT for Prediction
# estadocivil4-range_ is IMPORTANT for Prediction
# estadocivil5-min is NOT an important predictor. (Discard estadocivil5-min from model)
# estadocivil5-max is IMPORTANT for Prediction
# estadocivil5-sum is IMPORTANT for Prediction
# estadocivil5-range_ is IMPORTANT for Prediction
# estadocivil6-min is IMPORTANT for Prediction
# estadocivil6-max is IMPORTANT for Prediction
# estadocivil6-range_ is IMPORTANT for Prediction
# estadocivil7-min is NOT an important predictor. (Discard estadocivil7-min from model)
# estadocivil7-max is IMPORTANT for Prediction
# estadocivil7-sum is IMPORTANT for Prediction
# estadocivil7-range_ is IMPORTANT for Prediction
# parentesco1-min is NOT an important predictor. (Discard parentesco1-min from model)
# parentesco1-max is NOT an important predictor. (Discard parentesco1-max from model)
# parentesco1-sum is NOT an important predictor. (Discard parentesco1-sum from model)
# parentesco2-min is NOT an important predictor. (Discard parentesco2-min from model)
# parentesco2-max is IMPORTANT for Prediction
# parentesco3-min is NOT an important predictor. (Discard parentesco3-min from model)
# parentesco3-max is IMPORTANT for Prediction
# parentesco3-sum is IMPORTANT for Prediction
# parentesco4-min is NOT an important predictor. (Discard parentesco4-min from model)
# parentesco4-max is IMPORTANT for Prediction
# parentesco4-sum is IMPORTANT for Prediction
# parentesco5-min is NOT an important predictor. (Discard parentesco5-min from model)
# parentesco5-max is NOT an important predictor. (Discard parentesco5-max from model)
# parentesco6-min is NOT an important predictor. (Discard parentesco6-min from model)
# parentesco6-max is IMPORTANT for Prediction
# parentesco6-sum is IMPORTANT for Prediction
# parentesco7-min is NOT an important predictor. (Discard parentesco7-min from model)
# parentesco7-max is NOT an important predictor. (Discard parentesco7-max from model)
# parentesco8-min is NOT an important predictor. (Discard parentesco8-min from model)
# parentesco8-max is NOT an important predictor. (Discard parentesco8-max from model)
# parentesco9-min is NOT an important predictor. (Discard parentesco9-min from model)
# parentesco9-max is NOT an important predictor. (Discard parentesco9-max from model)
# parentesco9-sum is NOT an important predictor. (Discard parentesco9-sum from model)
# parentesco10-min is NOT an important predictor. (Discard parentesco10-min from model)
# parentesco10-max is NOT an important predictor. (Discard parentesco10-max from model)
# parentesco10-sum is NOT an important predictor. (Discard parentesco10-sum from model)
# parentesco11-min is NOT an important predictor. (Discard parentesco11-min from model)
# parentesco11-max is NOT an important predictor. (Discard parentesco11-max from model)
# parentesco11-sum is IMPORTANT for Prediction
# parentesco12-min is NOT an important predictor. (Discard parentesco12-min from model)
# parentesco12-max is NOT an important predictor. (Discard parentesco12-max from model)
# parentesco12-sum is NOT an important predictor. (Discard parentesco12-sum from model)
# instlevel1-min is IMPORTANT for Prediction
# instlevel1-max is IMPORTANT for Prediction
# instlevel1-sum is IMPORTANT for Prediction
# instlevel2-min is IMPORTANT for Prediction
# instlevel2-max is IMPORTANT for Prediction
# instlevel2-sum is IMPORTANT for Prediction
# instlevel2-range_ is IMPORTANT for Prediction
# instlevel3-min is IMPORTANT for Prediction
# instlevel3-max is IMPORTANT for Prediction
# instlevel3-sum is IMPORTANT for Prediction
# instlevel3-range_ is IMPORTANT for Prediction
# instlevel4-min is IMPORTANT for Prediction
# instlevel4-max is IMPORTANT for Prediction
# instlevel4-sum is IMPORTANT for Prediction
# instlevel4-range_ is IMPORTANT for Prediction
# instlevel5-min is NOT an important predictor. (Discard instlevel5-min from model)
# instlevel5-max is IMPORTANT for Prediction
# instlevel5-sum is IMPORTANT for Prediction
# instlevel6-min is NOT an important predictor. (Discard instlevel6-min from model)
# instlevel6-max is NOT an important predictor. (Discard instlevel6-max from model)
# instlevel6-sum is NOT an important predictor. (Discard instlevel6-sum from model)
# instlevel7-min is NOT an important predictor. (Discard instlevel7-min from model)
# instlevel7-max is IMPORTANT for Prediction
# instlevel7-sum is IMPORTANT for Prediction
# instlevel8-min is IMPORTANT for Prediction
# instlevel8-max is IMPORTANT for Prediction
# instlevel8-sum is IMPORTANT for Prediction
# instlevel8-range_ is IMPORTANT for Prediction
# instlevel9-min is NOT an important predictor. (Discard instlevel9-min from model)
# instlevel9-max is IMPORTANT for Prediction
# instlevel9-range_ is IMPORTANT for Prediction
# mobilephone-min is IMPORTANT for Prediction
# mobilephone-range_ is NOT an important predictor. (Discard mobilephone-range_ from model)
# escolari-min is IMPORTANT for Prediction
# escolari-max is IMPORTANT for Prediction
# escolari-sum is IMPORTANT for Prediction
# escolari-range_ is IMPORTANT for Prediction
# age-min is IMPORTANT for Prediction
# age-max is IMPORTANT for Prediction
# age-sum is NOT an important predictor. (Discard age-sum from model)
# age-range_ is IMPORTANT for Prediction

# %%
#Print list of variables to remove
remove_list
# Out:
# ['paredother',
#  'pisoother',
#  'techozinc',
#  'techoentrepiso',
#  'techootro',
#  'abastaguafuera',
#  'public',
#  'planpri',
#  'coopele',
#  'sanitario1',
#  'sanitario6',
#  'elimbasu5',
#  'elimbasu6',
#  'tipovivi1',
#  'tipovivi3',
#  'lugar2',
#  'lugar6',
#  'hhsize-diff',
#  'v18q-range_',
#  'male-max',
#  'male-range_',
#  'estadocivil1-min',
#  'estadocivil2-min',
#  'estadocivil5-min',
#  'estadocivil7-min',
#  'parentesco1-min',
#  'parentesco1-max',
#  'parentesco1-sum',
#  'parentesco2-min',
#  'parentesco3-min',
#  'parentesco4-min',
#  'parentesco5-min',
#  'parentesco5-max',
#  'parentesco6-min',
#  'parentesco7-min',
#  'parentesco7-max',
#  'parentesco8-min',
#  'parentesco8-max',
#  'parentesco9-min',
#  'parentesco9-max',
#  'parentesco9-sum',
#  'parentesco10-min',
#  'parentesco10-max',
#  'parentesco10-sum',
#  'parentesco11-min',
#  'parentesco11-max',
#  'parentesco12-min',
#  'parentesco12-max',
#  'parentesco12-sum',
#  'instlevel5-min',
#  'instlevel6-min',
#  'instlevel6-max',
#  'instlevel6-sum',
#  'instlevel7-min',
#  'instlevel9-min',
#  'mobilephone-range_',
#  'age-sum']

# %%
chi2_summary.sort_values('p-val', ascending = False).head(20)
# Out:
#           variable_name      chi2     p-val dof
# 95          v18q-range_  0.000000  1.000000   0
# 139     parentesco5-min  0.000000  1.000000   0
# 154    parentesco11-min  0.000000  1.000000   0
# 151    parentesco10-min  0.000000  1.000000   0
# 44            elimbasu5  0.000000  1.000000   0
# 148     parentesco9-min  0.000000  1.000000   0
# 146     parentesco8-min  0.000000  1.000000   0
# 144     parentesco7-min  0.000000  1.000000   0
# 157    parentesco12-min  0.000000  1.000000   0
# 141     parentesco6-min  0.000000  1.000000   0
# 136     parentesco4-min  0.000000  1.000000   0
# 133     parentesco3-min  0.000000  1.000000   0
# 131     parentesco2-min  0.000000  1.000000   0
# 130     parentesco1-sum  0.000000  1.000000   0
# 192  mobilephone-range_  0.000000  1.000000   0
# 129     parentesco1-max  0.000000  1.000000   0
# 105    estadocivil1-min  0.000000  1.000000   0
# 145     parentesco7-max  0.095483  0.992374   3
# 147     parentesco8-max  0.429518  0.934080   3
# 149     parentesco9-max  0.436543  0.932594   3

# %% [markdown]
# Notice that the top 17 p-valued variables have 0 chi-squared values. We hypothesize that this is because each variable only has one unique value of 0.00. Let us explore the data below:

# %%
cat_data.describe()
# Out:
#             Target       hacdor       hacapo         v14a       refrig  \
# count  2973.000000  2973.000000  2973.000000  2973.000000  2973.000000
# mean      3.359233     0.021191     0.012109     0.994282     0.952573
# std       0.987870     0.144044     0.109391     0.075414     0.212586
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.000000     0.000000     1.000000     1.000000
# 50%       4.000000     0.000000     0.000000     1.000000     1.000000
# 75%       4.000000     0.000000     0.000000     1.000000     1.000000
# max       4.000000     1.000000     1.000000     1.000000     1.000000
#
#        paredblolad  paredzocalo    paredpreb  pisocemento     pareddes  \
# count  2973.000000  2973.000000  2973.000000  2973.000000  2973.000000
# mean      0.603431     0.077699     0.183317     0.212916     0.008409
# std       0.489267     0.267743     0.386991     0.409438     0.091330
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#           ...       mobilephone-min  mobilephone-range_  escolari-min  \
# count     ...           2973.000000              2973.0   2973.000000
# mean      ...              0.958628                 0.0      4.419442
# std       ...              0.199183                 0.0      4.436783
# min       ...              0.000000                 0.0      0.000000
# 25%       ...              1.000000                 0.0      0.000000
# 50%       ...              1.000000                 0.0      4.000000
# 75%       ...              1.000000                 0.0      6.000000
# max       ...              1.000000                 0.0     21.000000
#
#        escolari-max  escolari-sum  escolari-range_      age-min      age-max  \
# count   2973.000000   2973.000000      2973.000000  2973.000000  2973.000000
# mean      10.508577     23.103263         6.089136    25.129499    52.891019
# std        4.066036     13.622448         4.669760    22.501855    16.385340
# min        0.000000      0.000000         0.000000     0.000000    18.000000
# 25%        7.000000     13.000000         2.000000     7.000000    40.000000
# 50%       11.000000     21.000000         6.000000    18.000000    53.000000
# 75%       14.000000     31.000000         9.000000    39.000000    64.000000
# max       21.000000    116.000000        21.000000    94.000000    97.000000
#
#            age-sum   age-range_
# count  2973.000000  2973.000000
# mean    110.140262    27.761520
# std      50.597781    18.612557
# min      18.000000     0.000000
# 25%      72.000000    10.000000
# 50%     105.000000    30.000000
# 75%     140.000000    39.000000
# max     373.000000    93.000000
#
# [8 rows x 201 columns]

# %% [markdown]
# Sure enough, we notice that the min/max for the values are all 0.00. Hence, it makes sense to remove them as recommended by the chi-squared test.
#
# Below, we explore the variables with highest chi-square values and lowest p-values just to get an idea of which variables might be more relevant to our model.

# %%
chi2_summary.sort_values('p-val', ascending = True).head(20)
# Out:
#          variable_name        chi2         p-val dof
# 194       escolari-max  551.196549  4.175911e-79  63
# 185     instlevel8-max  343.768796  3.333387e-74   3
# 186     instlevel8-sum  355.107887  1.794396e-66  15
# 23           cielorazo  269.867887  3.296470e-58   3
# 165     instlevel2-sum  314.605968  5.117338e-58  15
# 54               eviv3  264.249953  5.412945e-57   3
# 48             epared3  240.469091  7.534682e-52   3
# 14          pisomoscer  231.291915  7.269167e-50   3
# 187  instlevel8-range_  230.663695  9.938377e-50   3
# 193       escolari-min  372.596788  6.802357e-48  57
# 85           hogar_nin  294.001067  1.135355e-46  27
# 164     instlevel2-max  215.081289  2.322406e-46   3
# 51             etecho3  213.480363  5.151901e-46   3
# 5          paredblolad  203.405106  7.751450e-44   3
# 162     instlevel1-sum  245.630577  9.849553e-44  15
# 79                r4t1  242.258866  3.048177e-41  18
# 92            v18q-min  183.167940  1.825172e-39   3
# 107   estadocivil1-sum  223.753685  7.233576e-36  21
# 161     instlevel1-max  166.184123  8.480105e-36   3
# 166  instlevel2-range_  156.906998  8.522783e-34   3

# %% [markdown]
# Finally, we remove the variables that were recommended for removal by the chi-square test.

# %%
cat_data_selected = cat_data[cat_data.columns.difference(remove_list)]
cat_data_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2973 entries, 0 to 2972
# Columns: 147 entries, Id to v2a1-missing
# dtypes: bool(1), int64(144), object(2)
# memory usage: 3.3+ MB

# %% [markdown]
# ### 2. Correlation Matrix for Continuous Variables

# %%
#Get Continuous Variables from Data
cont_data = data[id_var + cont_var]
cont_data_noid = data[cont_var]
cont_data.head()
# Out:
#              Id    idhogar      v2a1  dependency  meaneduc  overcrowding  \
# 0  ID_279628684  21eb7fcc1  190000.0         0.0      10.0      1.000000
# 1  ID_f29eb3ddd  0e5d7a658  135000.0         8.0      12.0      1.000000
# 2  ID_68de51c94  2c7317ea8       0.0         8.0      11.0      0.500000
# 3  ID_ec05b1a7b  2b58d945f  180000.0         1.0      11.0      1.333333
# 4  ID_1284f8aad  d6dae86b7  130000.0         1.0      10.0      4.000000
#
#    v18q1  phones-per-capita  tablets-per-capita  rooms-per-capita  \
# 0    0.0               1.00                0.00              3.00
# 1    1.0               1.00                1.00              4.00
# 2    0.0               0.00                0.00              8.00
# 3    1.0               0.75                0.25              1.25
# 4    0.0               0.25                0.00              0.50
#
#    rent-per-capita  rez_esc-min  rez_esc-max  escolari-std    age-std
# 0         190000.0          0.0          0.0      0.000000   0.000000
# 1         135000.0          0.0          0.0      0.000000   0.000000
# 2              0.0          0.0          0.0      0.000000   0.000000
# 3          45000.0          0.0          1.0      4.272002  14.899664
# 4          32500.0          0.0          1.0      5.123475  11.690452

# %%
import matplotlib.pyplot as plt

pd.plotting.scatter_matrix(cont_data, figsize=(15, 15))
plt.show()
# Out:
# C:\Users\Wen Qing\Anaconda2\envs\BT4240\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Wen Qing\Anaconda2\envs\BT4240\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
#import seaborn as sns
#sns.set(style="ticks")

#scatter_data = cont_data + cat_data['Target']
#sns.pairplot(scatter_data, hue="Target")

# %%
print(cont_data_noid.corr())
# Out:
#                         v2a1  dependency  meaneduc  overcrowding     v18q1  \
# v2a1                1.000000   -0.109251  0.274625     -0.002674  0.193683
# dependency         -0.109251    1.000000 -0.164728     -0.104365 -0.080267
# meaneduc            0.274625   -0.164728  1.000000     -0.103958  0.323169
# overcrowding       -0.002674   -0.104365 -0.103958      1.000000 -0.060720
# v18q1               0.193683   -0.080267  0.323169     -0.060720  1.000000
# phones-per-capita   0.083683   -0.206604  0.262099     -0.317500  0.164730
# tablets-per-capita  0.176118   -0.041197  0.331145     -0.145521  0.863220
# rooms-per-capita   -0.015468    0.269584  0.069759     -0.664111 -0.003088
# rent-per-capita     0.829240   -0.098385  0.253816     -0.092661  0.122283
# rez_esc-min              NaN         NaN       NaN           NaN       NaN
# rez_esc-max        -0.011806    0.021939 -0.138290      0.239159 -0.075739
# escolari-std        0.107092   -0.193158  0.254637      0.244643  0.167700
# age-std            -0.051449   -0.257626  0.036321      0.293554  0.084213
#
#                     phones-per-capita  tablets-per-capita  rooms-per-capita  \
# v2a1                         0.083683            0.176118         -0.015468
# dependency                  -0.206604           -0.041197          0.269584
# meaneduc                     0.262099            0.331145          0.069759
# overcrowding                -0.317500           -0.145521         -0.664111
# v18q1                        0.164730            0.863220         -0.003088
# phones-per-capita            1.000000            0.245772          0.276356
# tablets-per-capita           0.245772            1.000000          0.170219
# rooms-per-capita             0.276356            0.170219          1.000000
# rent-per-capita              0.152924            0.180950          0.128879
# rez_esc-min                       NaN                 NaN               NaN
# rez_esc-max                 -0.108455           -0.088178         -0.202770
# escolari-std                -0.189500            0.052513         -0.414044
# age-std                     -0.196323           -0.033516         -0.527938
#
#                     rent-per-capita  rez_esc-min  rez_esc-max  escolari-std  \
# v2a1                       0.829240          NaN    -0.011806      0.107092
# dependency                -0.098385          NaN     0.021939     -0.193158
# meaneduc                   0.253816          NaN    -0.138290      0.254637
# overcrowding              -0.092661          NaN     0.239159      0.244643
# v18q1                      0.122283          NaN    -0.075739      0.167700
# phones-per-capita          0.152924          NaN    -0.108455     -0.189500
# tablets-per-capita         0.180950          NaN    -0.088178      0.052513
# rooms-per-capita           0.128879          NaN    -0.202770     -0.414044
# rent-per-capita            1.000000          NaN    -0.043985     -0.026875
# rez_esc-min                     NaN          NaN          NaN           NaN
# rez_esc-max               -0.043985          NaN     1.000000     -0.024578
# escolari-std              -0.026875          NaN    -0.024578      1.000000
# age-std                   -0.163117          NaN     0.124906      0.509562
#
#                      age-std
# v2a1               -0.051449
# dependency         -0.257626
# meaneduc            0.036321
# overcrowding        0.293554
# v18q1               0.084213
# phones-per-capita  -0.196323
# tablets-per-capita -0.033516
# rooms-per-capita   -0.527938
# rent-per-capita    -0.163117
# rez_esc-min              NaN
# rez_esc-max         0.124906
# escolari-std        0.509562
# age-std             1.000000

# %% [markdown]
# From the correlation matrix, we observe that only 2 variable pairs have relatively high correlations:
#     1. v2a1 and rent-per-capita
#     2. v18q1 and tablets-per-capita
#
# Which are expected since the latter variable in both pairs were features engineered from the former variable.
#
# In particular, dependancy and rez_esc-max seem to have lower levels of correlation with all other features. However, we decide to keep these as they represent the dependacy rate of members of the household, and maximum years behind in school by a member of the household - which intuitively might help in predicting our target feature.
#
# We also notice that rez_esc-min has NaN correlation with any variable - which suggests that it might have only one single value - 0.0. Let us explore that hypothesis:

# %%
cont_data_noid.describe()
# Out:
#                v2a1   dependency     meaneduc  overcrowding        v18q1  \
# count  2.973000e+03  2973.000000  2973.000000   2973.000000  2973.000000
# mean   5.159637e+04     1.334008     9.150342      1.375631     0.299697
# std    1.116788e+05     2.145635     4.387024      0.745672     0.655233
# min    0.000000e+00     0.000000     0.000000      0.200000     0.000000
# 25%    0.000000e+00     0.000000     6.000000      1.000000     0.000000
# 50%    0.000000e+00     0.500000     8.666667      1.333333     0.000000
# 75%    5.159637e+04     1.000000    12.000000      1.666667     0.000000
# max    2.353477e+06     8.000000    37.000000      6.000000     6.000000
#
#        phones-per-capita  tablets-per-capita  rooms-per-capita  \
# count        2973.000000         2973.000000       2973.000000
# mean            0.772636            0.100110          1.834929
# std             0.341416            0.230905          1.153828
# min             0.000000            0.000000          0.166667
# 25%             0.500000            0.000000          1.000000
# 50%             0.800000            0.000000          1.500000
# 75%             1.000000            0.000000          2.000000
# max             3.000000            3.000000          9.000000
#
#        rent-per-capita  rez_esc-min  rez_esc-max  escolari-std      age-std
# count      2973.000000       2973.0  2973.000000   2973.000000  2973.000000
# mean      19500.917430          0.0     0.218519      3.074326    14.022540
# std       48436.238407          0.0     0.703094      2.328856     8.773408
# min           0.000000          0.0     0.000000      0.000000     0.000000
# 25%           0.000000          0.0     0.000000      1.154701     7.071068
# 50%           0.000000          0.0     0.000000      3.000000    15.556349
# 75%       19500.917430          0.0     0.000000      4.509250    19.655364
# max     1000000.000000          0.0     5.000000     14.849242    42.829118

# %% [markdown]
# Sure enough, the min, max for rez_esc-min appears to be the same. We should remove this variable as it adds no value to our dataset.

# %%
cont_data_selected = cont_data[cont_data.columns.difference(['rez_esc-min'])]
cont_data_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2973 entries, 0 to 2972
# Data columns (total 14 columns):
# Id                    2973 non-null object
# age-std               2973 non-null float64
# dependency            2973 non-null float64
# escolari-std          2973 non-null float64
# idhogar               2973 non-null object
# meaneduc              2973 non-null float64
# overcrowding          2973 non-null float64
# phones-per-capita     2973 non-null float64
# rent-per-capita       2973 non-null float64
# rez_esc-max           2973 non-null float64
# rooms-per-capita      2973 non-null float64
# tablets-per-capita    2973 non-null float64
# v18q1                 2973 non-null float64
# v2a1                  2973 non-null float64
# dtypes: float64(12), object(2)
# memory usage: 348.4+ KB

# %% [markdown]
# ### Merge Categorical and Continuous Datasets

# %%
cont_data_selected = cont_data_selected.drop(columns = ['Id'] )
final_fs = cat_data_selected.merge(cont_data_selected, on = 'idhogar', how = 'left')
final_fs.head()
# Out:
#              Id  Target  abastaguadentro  abastaguano  age-max  age-min  \
# 0  ID_279628684       4                1            0       43       43
# 1  ID_f29eb3ddd       4                1            0       67       67
# 2  ID_68de51c94       4                1            0       92       92
# 3  ID_ec05b1a7b       4                1            0       38        8
# 4  ID_1284f8aad       4                1            0       30        7
#
#    age-range_  area1  area2  bedrooms    ...     escolari-std  meaneduc  \
# 0           0      1      0         1    ...         0.000000      10.0
# 1           0      1      0         1    ...         0.000000      12.0
# 2           0      1      0         2    ...         0.000000      11.0
# 3          30      1      0         3    ...         4.272002      11.0
# 4          23      1      0         1    ...         5.123475      10.0
#
#    overcrowding  phones-per-capita  rent-per-capita  rez_esc-max  \
# 0      1.000000               1.00         190000.0          0.0
# 1      1.000000               1.00         135000.0          0.0
# 2      0.500000               0.00              0.0          0.0
# 3      1.333333               0.75          45000.0          1.0
# 4      4.000000               0.25          32500.0          1.0
#
#    rooms-per-capita  tablets-per-capita  v18q1      v2a1
# 0              3.00                0.00    0.0  190000.0
# 1              4.00                1.00    1.0  135000.0
# 2              8.00                0.00    0.0       0.0
# 3              1.25                0.25    1.0  180000.0
# 4              0.50                0.00    0.0  130000.0
#
# [5 rows x 159 columns]

# %%
final_fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2973 entries, 0 to 2972
# Columns: 159 entries, Id to v2a1
# dtypes: bool(1), float64(12), int64(144), object(2)
# memory usage: 3.6+ MB

# %%
final_fs.to_csv('final_fs.csv')
